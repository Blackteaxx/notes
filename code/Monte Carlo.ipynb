# %%
import random
iters = 1000000

points = [(random.random(), random.random()) for _ in range(iters)]
inside = 0
for x,y in points:
    if x**2 + y**2 < 1:
        inside += 1

print("pi = ", 4 * inside / iters)
# Out:
# pi =  3.14004

# %%
import matplotlib.pyplot as plt

plt.scatter(*zip(*points), c=['red' if x**2 + y**2 < 1 else 'blue' for x,y in points])
plt.show()

# %% [markdown]
# 积分

# %%
# 求解y= x^2 + 1 在 [0,1] 上的定积分

iters = 1000000
total = 0
for _ in range(iters):
    x = random.random()
    total += x**2 + 1
    
print("integral = ", total / iters)
# Out:
# integral =  1.3333624019747707

# %% [markdown]
# Rejection Sampling

# %%
# 要从 p(x) 中采样
import math

def p(x):
    "Standard normal distribution"
    return math.exp(-x**2) / math.sqrt(2 * math.pi)

def accept(x,k):
    return p(x) / k

iters = 1000000
points = []
for _ in range(iters):
    x = random.uniform(-10, 10)
    u = random.random()
    if u < accept(x,1):
        points.append(x)
        
# 绘制直方图
plt.hist(points, bins=100, density=True)
plt.show()
